# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('Social_Network_Ads.csv')

# %%
data=data.iloc[:,2:]

# %%
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
x_train, y_train, x_test, y_test = train_test_split(data.drop('Purchased', axis=1),data['Purchased'],test_size=0.3)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (280, 2)
# (120, 2)
# (280,)
# (120,)

# %% [markdown]
# # Apply Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scaler=StandardScaler()
x_train_scaled=Scaler.fit_transform(x_train)
y_train_scaled=Scaler.transform(y_train)

# %%
x_train_scaled=pd.DataFrame(x_train_scaled, columns=x_train.columns)
y_train_scaled=pd.DataFrame(y_train_scaled, columns=y_train.columns)

# %%
print(x_train.describe())
print(x_train_scaled.describe())
# Out:
#               Age  EstimatedSalary
# count  280.000000       280.000000
# mean    37.685714     69567.857143
# std     10.747400     34639.604342
# min     18.000000     15000.000000
# 25%     29.000000     43000.000000
# 50%     37.000000     70000.000000
# 75%     46.000000     87000.000000
# max     60.000000    150000.000000
#                 Age  EstimatedSalary
# count  2.800000e+02     2.800000e+02
# mean   2.410770e-16    -6.661338e-17
# std    1.001791e+00     1.001791e+00
# min   -1.834952e+00    -1.578123e+00
# 25%   -8.096159e-01    -7.683525e-01
# 50%   -6.391705e-02     1.249774e-02
# 75%    7.749942e-01     5.041442e-01
# max    2.079967e+00     2.326128e+00

# %%
print(y_train.describe())
print(y_train_scaled.describe())
# Out:
#               Age  EstimatedSalary
# count  120.000000       120.000000
# mean    37.583333     70150.000000
# std      9.881298     32934.528891
# min     18.000000     15000.000000
# 25%     30.000000     46500.000000
# 50%     37.000000     69000.000000
# 75%     46.000000     88000.000000
# max     59.000000    150000.000000
#               Age  EstimatedSalary
# count  120.000000       120.000000
# mean    -0.009543         0.016836
# std      0.921059         0.952479
# min     -1.834952        -1.578123
# 25%     -0.716404        -0.667131
# 50%     -0.063917        -0.016423
# 75%      0.774994         0.533065
# max      1.986755         2.326128

# %% [markdown]
# # Graphs

# %% [markdown]
# # Effect of Scaling

# %%
fig, (ax1, ax2)=plt.subplots(ncols=2, figsize=(12,5))
ax1.set_title("Before Scaling")
ax1.scatter(x_train['Age'],x_train['EstimatedSalary'])
ax2.set_title("After Scaling")
ax2.scatter(x_train_scaled['Age'],x_train_scaled['EstimatedSalary'])
